# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Quantum Computer Image</title>
# </head>
# <body>
#     <h2>IBM Q Quantum Computer</h2>
#     <img
#         src="https://www.cnet.com/a/img/resize/c7cb26e927bebaa784fb55a01e71d7fecb15d2e3/hub/2019/06/26/3f76e99d-8055-46f3-8f27-558ee276b665/20180405-ibm-q-quantum-computer-02.jpg?auto=webp&fit=crop&height=675&width=1200"
#         alt="IBM Q Quantum Computer"
#         width="800"
#         style="border: 1px solid #ccc; box-shadow: 2px 2px 6px rgba(0,0,0,0.2);"
#     >
# </body>
# </html>

# %%
import time

# %% [raw]
# time.clock_gettime

# %%
# !ls
# Out:
# logs                                    Section_5_1_TensorFlow_Examples.ipynb
# README.md                               Section_5_2_Pytorch_Examples.ipynb
# requirements.txt                        Section_5_3_TF_deep_vs_Shallow.ipynb
# run_tensorboard.sh                      Section_5_4_TF_Keras_tuner.ipynb
# Section_1_1-Tensorflow-Tensorboard.py   Section_5_5_PyTorch_Optuna.ipynb
# Section_1_2-Keras-Tensorborad.py        Section_7_Chatbot.ipynb
# Section_1_3-Pytorch-Relu.py             Section_7_Sentiment_Analysis.ipynb
# Section_2_Jupyter_Intro.ipynb           Section_7_Text_Summarization.ipynb
# Section_2_Model_Training_Example.ipynb  Section_test_notebook.ipynb
# Section_3_2_scikit_learn_examples.ipynb Tools
# Section_3_Python_intro.ipynb            venv

# %%
# !pip install torch
