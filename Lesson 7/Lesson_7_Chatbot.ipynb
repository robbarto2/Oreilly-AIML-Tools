# %%
from transformers import pipeline

# Create the pipeline
chatbot = pipeline("text2text-generation", model="facebook/blenderbot-400M-distill")
# Out:
# Device set to use mps:0

# %%
conversation = chatbot("What have you been up to")

# %%
conversation
# Out:
# [{'generated_text': " I've been working on a project for work. It's a lot of work, but it's worth it in the end."}]

# %%
conversation = chatbot("I'm more of a cat person. How do you feel about cats?")

# %%
conversation
# Out:
# [{'generated_text': " I love cats! I have two of my own. They're great companions and they're great at hunting vermin."}]

# %%
conversation = chatbot("Do you like movies?")

# %%
conversation

# %% [raw]
# Run as a chatbot with Gradio

# %%
import gradio as gr

message_list = []
response_list = []

def favourite_chatbot(message, history):
    conversation = chatbot(message)
    
    return conversation[0]['generated_text']

demo_chatbot = gr.ChatInterface(favourite_chatbot, title="Favourite Chatbot", description="Enter text to start chatting.")

demo_chatbot.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
